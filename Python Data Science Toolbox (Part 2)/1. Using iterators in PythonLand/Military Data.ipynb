# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
military = pd.read_csv('Military Expenditure.csv', delimiter = ',')
military.shape
# Out:
# (264, 63)

# %%
x.shape

# %%
money = military.iloc[:,4:]
money.shape
# Out:
# (264, 59)

# %%
money.head()
# Out:
#    1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#            2009          2010          2011          2012          2013  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.518695e+08  2.981469e+08  3.258070e+08  2.385834e+08  2.171941e+08
# 2  3.311193e+09  3.500795e+09  3.639496e+09  4.144635e+09  6.090752e+09
# 3  1.827369e+08  1.858932e+08  1.970068e+08  1.832047e+08  1.800155e+08
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2014          2015          2016          2017          2018
# ...

# %%
y = [num for num in x.iloc[1,4:] if str(num) != 'nan']
z = sum(y)
z

# %%
tot_spend = []

for n in money:
  #  total = [num for num in x.iloc[n, 4:] if str(num) != 'nan']
    total = [num for num in money if str(num) != 'nan']
    tot_spend.append(total)

# %%
military['Total'] = money.sum(axis = 1)
military.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2010          2011          2012  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.981469e+08  3.258070e+08  2.385834e+08
# 2   NaN   NaN   NaN   NaN  ...  3.500795e+09  3.639496e+09  4.144635e+09
# 3   NaN   NaN   NaN   NaN  ...  1.858932e+08  1.970068e+08  1.832047e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
import os
wd = os.getcwd()
os.listdir(wd)
# Out:
# ['.ipynb_checkpoints',
#  'F500.csv',
#  'F501.csv',
#  'Military Data.ipynb',
#  'Military Expenditure.csv',
#  'Python Data Science Toolbox (Part 2).ipynb']
