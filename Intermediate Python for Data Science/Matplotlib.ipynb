# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set(style="darkgrid")
data = pd.read_csv('F500.csv')

np_data = np.array(data)

print(np_data)
# Out:
# [['619"']
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  ['011"']
#  ['761"']
#  [nan]
#  [nan]
#  [nan]
#  ['516"']
#  ['182"']
#  [nan]
#  [nan]
#  [nan]
#  ['394"']
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  ['612"']
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Разделение данных происходит благодаря параметру delimiter. Следует указать разделитель между данными. 
# Чтобы узнать тип разделителя данных, посмотри файл csv в jupyter. Чаще всего это ; или ,
# Данные загружаются по умолчанию в формате float. Измени данные на str с помощью параметра dtype
np_data = np.loadtxt('goldprices2.csv', delimiter=';', skiprows = 1, dtype = int, usecols = (0,2))
np_date = np.loadtxt('goldprices2.csv', delimiter=';', skiprows = 1, dtype = str, usecols = 1)
#np_array = np.array(int(np_data))

print(np_data.shape)
print(np_data)
print(np_date)
# Out:
# (817, 2)
# [[   1   34]
#  [   2   34]
#  [   3   34]
#  ...
#  [ 815 1265]
#  [ 816 1332]
#  [ 817 1333]]
# ['01.02.1950' '01.03.1950' '01.04.1950' '01.05.1950' '01.06.1950'
#  '01.07.1950' '01.08.1950' '01.09.1950' '01.10.1950' '01.11.1950'
#  '01.12.1950' '01.01.1951' '01.02.1951' '01.03.1951' '01.04.1951'
#  '01.05.1951' '01.06.1951' '01.07.1951' '01.08.1951' '01.09.1951'
#  '01.10.1951' '01.11.1951' '01.12.1951' '01.01.1952' '01.02.1952'
#  '01.03.1952' '01.04.1952' '01.05.1952' '01.06.1952' '01.07.1952'
#  '01.08.1952' '01.09.1952' '01.10.1952' '01.11.1952' '01.12.1952'
#  '01.01.1953' '01.02.1953' '01.03.1953' '01.04.1953' '01.05.1953'
#  '01.06.1953' '01.07.1953' '01.08.1953' '01.09.1953' '01.10.1953'
#  '01.11.1953' '01.12.1953' '01.01.1954' '01.02.1954' '01.03.1954'
#  '01.04.1954' '01.05.1954' '01.06.1954' '01.07.1954' '01.08.1954'
#  '01.09.1954' '01.10.1954' '01.11.1954' '01.12.1954' '01.01.1955'
#  '01.02.1955' '01.03.1955' '01.04.1955' '01.05.1955' '01.06.1955'
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

np_revenue = np.loadtxt('F5002.csv', delimiter = ";", skiprows = 1, dtype = int, usecols = (-6, -1))

print(np_revenue.shape)
print(np_revenue)
# Out:
# (500, 2)
# [[485873 218619]
#  [223604 411035]
#  [215639 753718]
#  [205004 340056]
#  [192487  31439]
#  [184840 157793]
#  [177526  81310]
#  [166380  52968]
#  [163786 255679]
#  [151800  46349]
#  [146850  19229]
#  [135987 423031]
#  [126661 259520]
#  [125980 198900]
#  [121546  25725]
#  [118719  73606]
#  [117351  89645]
#  [115337  26961]
#  [107567 203263]
#  [107162   3011]
#  [105486 313761]
#  [100288  39567]
#  [ 94595 176368]
#  [ 94571 107546]
#  [ 94176 278516]
#  [ 93662 236182]
#  [ 90272 579426]
#  [ 85320 508935]
#  [ 84863  43813]
#  [ 82386 165394]
#  [ 80403 178258]
#  [ 79919 164251]
#  [ 76132      0]
#  [ 72396  40954]
#  [ 71890 337642]
#  [ 71726 229700]
#  [ 70166  29746]
#  [ 69495  30502]
#  [ 65665   1612]
#  [ 65017  70481]
#  [ 64806      0]
#  [ 63476  57429]
#  [ 63155  44859]
#  [ 62799 159763]
#  [ 62346  26274]
#  [ 60906  93276]
#  [ 59387 170539]
#  [ 58779  45912]
#  [ 58734      0]
#  [ 57244  89957]
#  [ 55858  26679]
#  [ 55632 179298]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

np_employee = np.loadtxt('F500.csv', delimiter = ";", skiprows = 1, dtype = float, usecols = 3)


print(np_employee.shape)
print(np_employee)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0fe847536c73> in <module>
#       4 import numpy as np
#       5
# ----> 6 np_employee = np.loadtxt('F500.csv', delimiter = ";", skiprows = 1, dtype = float, usecols = 3)
#       7
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1139         # converting the data
#    1140         X = None
# -> 1141         for x in read_data(_loadtxt_chunksize):
#    1142             if X is None:
#    1143                 X = np.array(x, dtype)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1066
#    1067             # Convert each value according to its column and store
# ...

# %%
import pandas as pd

# параметр index_col=0 в pd.read_csv убирает автоматические индексы, начинающиеся с нуля. 
# Если же индекс нужен и нужно, чтобы он начинался с одного, а не с 0, то добавь index_col = 1
# Так выглядит всё таки лучше, если в таблице уже есть рейтинг:
# fortune = pd.read_csv('F500.csv', delimiter = ";", index_col = 1)

fortune = pd.read_csv('F500.csv', delimiter = ";", index_col = 1)

#to print out dataframe use double square name_of_the_Panda_csv_file[['first column', 'second', 'so on']]

#print(fortune[['name', 'employees',"revenues","profits","marketvalue"]])

print(fortune.loc[:,['name', 'employees', 'revenues', 'profits','marketvalue']])
# Out:
#                                     name  employees  revenues     profits  \
# rank
# 1                                Walmart  2,300,000  $485,873  $13,643.0
# 2                     Berkshire Hathaway    367,700  $223,604  $24,074.0
# 3                                  Apple    116,000  $215,639  $45,687.0
# 4                            Exxon Mobil     72,700  $205,004   $7,840.0
# 5                               McKesson     68,000  $192,487   $2,258.0
# 6                     UnitedHealth Group    230,000  $184,840   $7,017.0
# 7                             CVS Health    204,000  $177,526   $5,317.0
# 8                         General Motors    225,000  $166,380   $9,427.0
# 9                                   AT&T    268,540  $163,786  $12,976.0
# 10                            Ford Motor    201,000  $151,800   $4,596.0
# 11                     AmerisourceBergen     18,500  $146,850   $1,427.9
# 12                            Amazon.com    341,400  $135,987   $2,371.0
# ...

# %%
pd_data = pd.read_csv('F500.csv')
pd_data.head()
# Out:
#                                                                                                                          id;"rank";"name";"employees";"previousrank";"revenues";"revenuechange";"profits";"profitschange";"assets";"marketvalue"
# 2;"1";"Walmart";"2              300            000";"1";"$485    873";"0.8%";"$13       643.0 ";"-7.2%";"$198 825";"$218                                               619"
# 3;"2";"Berkshire Hathaway";"367 700";"4";"$223 604";"6.1%";"$24  074.0 ";"0.0%";"$620   854";"$411            035"                                                      NaN
# 4;"3";"Apple";"116              000";"3";"$215 639";"-7.7%";"$45 687.0 ";"-14.4%";"$321 686";"$753            718"                                                      NaN
# 5;"4";"Exxon Mobil";"72         700";"2";"$205 004";"-16.7%";"$7 840.0 ";"-51.5%";"$330 314";"$340            056"                                                      NaN
# ...

# %%
import pandas as pd

# параметр index_col=0 в pd.read_csv убирает автоматические индексы, начинающиеся с нуля. 
# Если же индекс нужен и нужно, чтобы он начинался с одного, а не с 0, то добавь index_col = 1
# Так выглядит всё таки лучше, если в таблице уже есть рейтинг:
# fortune = pd.read_csv('F500.csv', delimiter = ";", index_col = 1)

fortune = pd.read_csv('F5002.csv', delimiter = ";", index_col = 0)

#to print out dataframe use double square name_of_the_Panda_csv_file[['first column', 'second', 'so on']]

#print(fortune[['name', 'employees',"revenues","profits","marketvalue"]])

#fortune_rate = fortune.loc[:,['name', 'employees', 'revenues', 'profits']]
#print(fortune_rate)

employees = fortune['employees'] > 100000

fortune[employees]
# Out:
#      rank                   name  employees  previousrank  revenues  \
# id
# 2       1                Walmart    2300000           1.0    485873
# 22     21      J.P. Morgan Chase     243355          23.0    105486
# 27     26  Bank of America Corp.     208024          26.0     93662
# 59     58                  FedEx     335767          58.0     50365
# 135   134       Tenet Healthcare     116475         140.0     21070
# 386   385     Darden Restaurants     150942         371.0      6934
#
#     revenuechange    profits profitschange     assets marketvalue,,,
# id
# 2            0.8%  13,643.0          -7.2%    198,825        218619,
# 22           4.4%  24,733.0           1.2%  2,490,972         313761
# 27           0.7%  17,906.0          12.7%  2,187,702         236182
# 59           6.1%   1,820.0          73.3%     46,064         52178,
# 135          4.8%    -192.0              0     24,701         1777,,
# ...
